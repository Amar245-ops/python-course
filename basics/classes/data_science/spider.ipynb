# %%
from dputils import scrape as sc
import pandas as pd

# %%
query = 'laptops'
url = f'https://www.amazon.in/s?k={query}'
print(url)
soup = sc.get_webpage_data(url)
# Out:
# https://www.amazon.in/s?k=laptops

# %%
target = {'tag':'div', 'attrs':{'class': 's-main-slot s-result-list s-search-results sg-row' }}
items = {'tag':'div','attrs':{'class': 's-result-item'}}
title = {'tag':'h2','attrs':{'class':'a-size-mini a-spacing-none a-color-base s-line-clamp-2'}}
price = {'tag':'span','attrs':{'class':'a-price-whole'}}
rating = {'tag':'div','attrs':{'class':'a-section a-spacing-none a-spacing-top-micro'}}

# %%
output = sc.extract_many(
    soup,
    target=target,
    items=items,
    title=title,
    price=price,
    rating=rating)
# Out:
# 37 items found
# Item skipped at index: 0
# Item skipped at index: 1
# Item skipped at index: 8
# Item skipped at index: 9
# Item skipped at index: 10
# Item skipped at index: 11
# Item skipped at index: 12
# Item skipped at index: 13
# Item skipped at index: 14
# Item skipped at index: 32
# Item skipped at index: 33
# Item skipped at index: 34
# Item skipped at index: 35
# Item skipped at index: 36
# All items extracted

# %%
df = pd.DataFrame(output)
df
# Out:
#                                                 title     price  \
# 0   Samsung Galaxy Book2 Intel 12th Gen core i5 39...    69,990
# 1   HP 15s 12th Gen Intel Core i5 8GB RAM/512GB SS...    57,990
# 2   ASUS VivoBook 14 (2021), 14-inch (35.56 cm) HD...    28,990
# 3   Dell XPS 9720 Laptop, Intel i9-12900HK, 32GB D...  2,44,770
# 4   ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) ...    25,990
# 5   ASUS ZenBook 14 (2020) Intel Core i5-1135G7 11...    78,989
# 6   Lenovo IdeaPad Slim 3 Intel Celeron N4020 15.6...    27,290
# 7   Lenovo IdeaPad Slim 1 Intel Celeron N4020 11.6...    21,789
# 8   HP 15- AMD Ryzen 3-3250U 15.6 inch(39.6 cm) FH...    38,999
# 9   HP NB 255 G8 Laptop (AMD Ryzen 3-3250U/8GB DDR...    29,385
# 10  Lenovo IdeaPad Slim 3 Intel Core i3 10th Gen 1...    32,990
# 11  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 1...    39,490
# 12  Samsung Galaxy Book2 Pro 360 Intel 12th Gen i7...  1,29,990
# 13  Lenovo IdeaPad Gaming 3 Intel Core i5 10th Gen...    53,990
# 14  HP 14s, 5th Gen AMD Ryzen 3- 8GB RAM/512GB SSD...    38,490
# 15  Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen 1...    59,490
# 16  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, A...    44,200
# 17  HP 15s, 11th Gen Intel Core i3, 8GB RAM/512GB ...    42,990
# 18  Dell Inspiron 3525 Laptop, AMD Athlon Silver 3...    31,990
# 19  Acer Extensa 15 Thin & Light Intel Processor P...    24,999
# 20  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 1...    38,990
# 21  Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen 1...    59,490
# 22  LG Gram 17 Intel Evo 11th Gen i5 Thin & Light ...    74,000
#
#                                                rating
# 0                               3.6 out of 5 stars 26
# 1                               3.6 out of 5 stars 92
# 2                              2.4 out of 5 stars 103
# 3   Get it by Sunday, August 21FREE Delivery by Am...
# 4                            4.1 out of 5 stars 1,576
# 5                              4.4 out of 5 stars 463
# 6                               3.6 out of 5 stars 48
# 7                              3.9 out of 5 stars 568
# 8                            4.2 out of 5 stars 3,963
# 9                               3.2 out of 5 stars 66
# 10                             3.6 out of 5 stars 530
# 11                             4.1 out of 5 stars 220
# 12                              3.6 out of 5 stars 20
# 13                             4.1 out of 5 stars 242
# 14                           4.2 out of 5 stars 3,963
# 15                              3.4 out of 5 stars 26
# 16                              4.2 out of 5 stars 53
# 17                              4.3 out of 5 stars 85
# 18                              4.2 out of 5 stars 82
# 19                             3.3 out of 5 stars 257
# 20                             4.1 out of 5 stars 220
# 21                              3.4 out of 5 stars 26
# 22                              4.8 out of 5 stars 20
