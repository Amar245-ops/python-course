# %%
from PIL import Image, ImageDraw, ImageFilter, ImageEnhance

# %%
im = Image.open(r'C:\Users\Amardeep\Desktop\download.jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=349x144>

# %%
im.size
# Out:
# (349, 144)

# %%
im.mode
# Out:
# 'RGB'

# %%
im.format
# Out:
# 'JPEG'

# %%
im.show()

# %%
thumb = im.copy()
thumb.thumbnail((100, 100))
thumb.save('thumbnail.jpg')

# %%
thumb
# Out:
# <PIL.Image.Image image mode=RGB size=100x41>

# %%
im.resize((400, 400))
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
w,h = im.size
im.resize(w*2, h*2, Image.Resampling.BILINEAR)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\pythoncourse\basics\classes\data_science\image_processing.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/pythoncourse/basics/classes/data_science/image_processing.ipynb#ch0000010?line=0'>1</a> w,h = im.size
# ----> <a href='vscode-notebook-cell:/e%3A/pythoncourse/basics/classes/data_science/image_processing.ipynb#ch0000010?line=1'>2</a> im.resize(w*2, h*2, Image.Resampling.BILINEAR)
#
# File c:\Users\Amardeep\miniconda3\lib\site-packages\PIL\Image.py:2018, in Image.resize(self, size, resample, box, reducing_gap)
#    2005     message = f"Unknown resampling filter ({resample})."
#    2007     filters = [
#    2008         f"{filter[1]} ({filter[0]})"
#    2009         for filter in (
#    (...)
#    2016         )
#    2017     ]
# -> 2018     raise ValueError(
#    2019         message + " Use " + ", ".join(filters[:-1]) + " or " + filters[-1]
#    2020     )
#    2022 if reducing_gap is not None and reducing_gap < 1.0:
#    2023     raise ValueError("reducing_gap must be 1.0 or greater")
#
# ValueError: Unknown resampling filter (288). Use Image.Resampling.NEAREST (0), Image.Resampling.LANCZOS (1), Image.Resampling.BILINEAR (2), Image.Resampling.BICUBIC (3), Image.Resampling.BOX (4) or Image.Resampling.HAMMING (5)

# %%
im.filter(ImageFilter.BLUR).show()

# %%
im.filter(ImageFilter.CONTOUR).show()
im.filter(ImageFilter.DETAIL).show()
im.filter(ImageFilter.EDGE_ENHANCE_MORE).show()
im.filter(ImageFilter.EMBOSS).show()
im.filter(ImageFilter.FIND_EDGES).show()
im.filter(ImageFilter.BLUR).show()
im.filter(ImageFilter.SHARPEN).show()
im.filter(ImageFilter.MaxFilter(3)).show()
im.filter(ImageFilter.SMOOTH).show()
im.filter(ImageFilter.SMOOTH_MORE).show()
im.filter(ImageFilter.MinFilter(3)).show()
im.filter(ImageFilter.MedianFilter(3)).show()
im.filter(ImageFilter.ModeFilter(3)).show()
im.filter(ImageFilter.GaussianBlur(40)).show()
